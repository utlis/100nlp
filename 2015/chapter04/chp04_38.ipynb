# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
matplotlib.style.use('ggplot')
matplotlib.pylab.rcParams['figure.figsize'] = 14,10
# fontprop = matplotlib.font_manager.FontProperties(fname="/Users/shuntaroy/Library/Fonts/rounded-mgenplus-2cp-regular.ttf")
matplotlib.pylab.rcParams['font.family'] = 'IPAexGothic'

# %%
import chp04_36 as p36

# %%
counter = p36.main()

# %% [markdown]
# ###全体を10分割したヒストグラム

# %%
freq = pd.Series(list(counter.values()),index=list(counter.keys()))
freq.hist()

# %% [markdown]
# ### 上位50件を50分割したヒストグラム

# %%
freq.plot(kind='hist', bins=range(50))

# %%
print(len(counter.values()))
print(len(list(counter.values())))
print(len(counter))
# Out:
# 13584
# 13584
# 13584
